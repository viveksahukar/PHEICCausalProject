# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data = pd.read_csv('Stockprice.csv')

# %%
data.head()
# Out:
#          Company  Date  StockPrice  Revenue
# 0  Luckin Coffee     0       37.12      1.0
# 1  Luckin Coffee     0       39.61      1.0
# 2  Luckin Coffee     0       37.87      1.0
# 3  Luckin Coffee     1       36.40      1.0
# 4  Luckin Coffee     1       32.49      1.0

# %%
plt.figure(figsize = (15,10))
for company in set(data['Company']):
    
    plt.plot(data[data['Company'] == company]['StockPrice'].values, label = company)

plt.legend()

# %%
did = smf.ols(formula='StockPrice ~ Date*Revenue', data=data).fit()

# %%
did.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             StockPrice   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     3.244
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):             0.0274
# Time:                        12:47:04   Log-Likelihood:                -387.56
# No. Observations:                  70   AIC:                             783.1
# Df Residuals:                      66   BIC:                             792.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
did = smf.ols(formula='StockPrice ~ Date*Revenue', data=data_new).fit()

# %%
did.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             StockPrice   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     1.800
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.157
# Time:                        14:59:52   Log-Likelihood:                -349.27
# No. Observations:                  63   AIC:                             706.5
# Df Residuals:                      59   BIC:                             715.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
data_new = data[(data['Company'] != 'lenovo') & (data['Company']!='Bank of China')]

# %%
# aggregate
data_china = data[data['Revenue'] > 0.5]
data_inter = data[data['Revenue'] < 0.5]

# %%
data_china
# Out:
#                   Company  Date  StockPrice  Revenue
# 0           Luckin Coffee     0     37.1200     1.00
# 1           Luckin Coffee     0     39.6100     1.00
# 2           Luckin Coffee     0     37.8700     1.00
# 3           Luckin Coffee     1     36.4000     1.00
# 4           Luckin Coffee     1     32.4900     1.00
# 5           Luckin Coffee     1     31.3500     1.00
# 6           Luckin Coffee     1     36.2400     1.00
# 7                 Alibaba     0    205.4700     0.94
# 8                 Alibaba     0    210.2300     0.94
# 9                 Alibaba     0    212.0200     0.94
# 10                Alibaba     1    208.5800     0.94
# 11                Alibaba     1    206.5900     0.94
# 12                Alibaba     1    213.1000     0.94
# 13                Alibaba     1    222.8800     0.94
# 14  China Eastern Airline     0     22.4000     0.99
# 15  China Eastern Airline     0     22.8400     0.99
# 16  China Eastern Airline     0     23.2900     0.99
# ...

# %%
data['Revenue'].hist()

# %%
# aggregate
data_china = data[data['Revenue'] > 0.2]
data_inter = data[data['Revenue'] < 0.2]

# %%
import numpy as np
data_china['ActualDate'] = np.tile(np.arange(7),12)
data_inter['ActualDate'] = np.tile(np.arange(7), 17)

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax.set_xlim([0, 6])
sns.regplot(x = 'ActualDate', y = 'StockPrice', data = data_inter,
                        color = 'b', ax = ax, scatter = False, truncate = True, label='treat')
